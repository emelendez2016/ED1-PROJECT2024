# %%
import pandas as pd
import numpy as np
from scipy.stats import skew, kurtosis
from scipy.signal import welch
import os

# CHANGE DIRECTORY TO YOUR PROCESSED EEGS!!!!!
processed_eegs_dir = "/Users/estuardomelendez/Desktop/processed_eegs"
processed_files = [os.path.join(processed_eegs_dir, f) for f in os.listdir(processed_eegs_dir) if f.endswith(".parquet")]

# Sampling frequency (Hz) and window size (in seconds)
fs = 400  # Updated sampling frequency to match professor's files
window_size_seconds = 2  # Duration of each window in seconds
window_size_samples = fs * window_size_seconds

# Define EEG frequency bands
bands = {
    "delta": (1, 3),
    "theta": (4, 7),
    "alpha1": (8, 9),
    "alpha2": (10, 12),
    "beta1": (13, 17),
    "beta2": (18, 30),
    "gamma1": (31, 40),
    "gamma2": (41, 50),
    "higher": (51, 250)
}

# List of 19 standard EEG channels
expected_channels = [
    "Fp1", "Fp2", "F3", "F4", "C3", "C4", "P3", "P4", "O1", "O2",
    "F7", "F8", "T3", "T4", "T5", "T6", "Fz", "Cz", "Pz"
]

# Function to split data into windows
def split_into_windows(signal, window_size):
    num_windows = len(signal) // window_size
    return [signal[i * window_size:(i + 1) * window_size] for i in range(num_windows)]

# Function to extract time-domain features
def extract_time_features(signal):
    return {
        "mean": np.mean(signal),
        "variance": np.var(signal),
        "skewness": skew(signal),
        "kurtosis": kurtosis(signal),
        "rms": np.sqrt(np.mean(signal**2)),
        "zero_crossing_rate": np.sum(np.diff(np.sign(signal)) != 0) / len(signal),
        "mean_abs": np.mean(np.abs(signal)),
        "diff_rms1": np.sqrt(np.mean(np.diff(signal) ** 2)),
        "diff_rms2": np.sqrt(np.mean(np.diff(signal, n=2) ** 2))
    }

# Function to extract frequency-domain features using FFT
def extract_frequency_features(signal, fs):
    L = len(signal)
    Y = np.fft.fft(signal)
    P2 = np.abs(Y / L)
    P1 = P2[:L // 2 + 1]
    P1[1:-1] *= 2
    freqs = fs * np.arange(L // 2 + 1) / L
    
    band_powers = {name: np.sum(P1[(freqs >= low) & (freqs <= high)]) for name, (low, high) in bands.items()}
    band_powers["spectral_entropy"] = -np.sum(P1 * np.log(P1 + 1e-10))
    return band_powers

# Function to extract features from a single EEG file
def extract_features_from_file(file_path, fs, window_size_samples):
    data = pd.read_parquet(file_path)
    available_channels = [ch for ch in expected_channels if ch in data.columns]
    
    if len(available_channels) < len(expected_channels):
        print(f"Warning: Some expected EEG channels are missing in {file_path}")
    
    all_features = []
    
    for channel in available_channels:
        signal = data[channel].values
        windows = split_into_windows(signal, window_size_samples)
        
        for i, window in enumerate(windows):
            time_features = extract_time_features(window)
            frequency_features = extract_frequency_features(window, fs)
            
            combined_features = {
                "file": os.path.basename(file_path),
                "channel": channel,
                "window": i,
                **time_features,
                **frequency_features
            }
            all_features.append(combined_features)
    
    return pd.DataFrame(all_features)

# Process all files
combined_features = []
for file_path in processed_files:
    print(f"Extracting features from: {file_path}")
    file_features = extract_features_from_file(file_path, fs, window_size_samples)
    combined_features.append(file_features)

# Combine features from all files into a single DataFrame
all_features_df = pd.concat(combined_features, ignore_index=True)

# Save extracted features to a CSV file
output_feature_file = "/Users/estuardomelendez/Desktop/processed_eegs/eeg_features.csv"
all_features_df.to_csv(output_feature_file, index=False)

# Preview extracted features
print(f"Features saved to: {output_feature_file}")
print("\nPreview of Extracted Features:")
print(all_features_df.head())
# Out:
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/4222573799.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/1622210937.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/678648250.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2148256831.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/1469546440.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3329232596.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2718549792.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2510219397.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2436487142.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2014107973.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/1037773381.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/413742710.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2484641754.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/4099033954.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2302302452.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/837639030.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3854492726.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3715407957.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/839230176.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/1573558442.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/1039058822.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3945925489.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/1687123085.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2015905115.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3204007697.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/1809434330.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3383534481.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/4285210475.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2752736460.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/231432766.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/1765478799.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/4257527824.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3859607471.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3064792501.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/481358497.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/4010993438.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2894643287.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2132912634.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/1330263395.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2740692471.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2411672943.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/992798064.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/527970310.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/1655308883.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2322119862.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2573770198.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/175001942.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3900459244.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/280907771.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3184243660.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/4215350496.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3751149087.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3774430289.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/369912379.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/8922554.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/465677924.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/1504413365.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2964873930.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/679047082.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/688446763.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2090900070.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3158461194.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3485489953.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3268523216.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2320261988.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/1326562309.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/77987479.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3630706891.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3287904898.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/330358359.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/1791299141.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2396110242.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3500185798.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3646330278.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2530656361.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3701641197.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2539873802.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3568435119.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3572902772.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2209965074.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3552918494.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/1315636310.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2495006719.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/4014410930.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/878032028.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2701220687.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/1468936383.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2941389142.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/1122434994.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/598783499.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/1198730722.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/4246314327.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3279947709.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/2346697031.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/1085571772.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/1986250709.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/3254156300.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/1457534413.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/4045810693.parquet
# Extracting features from: /Users/estuardomelendez/Desktop/processed_eegs/801924332.parquet
# Features saved to: /Users/estuardomelendez/Desktop/processed_eegs/eeg_features.csv
#
# Preview of Extracted Features:
#                  file channel  window      mean  variance  skewness  kurtosis  \
# 0  4222573799.parquet     Fp1       0  0.000642  0.663819  0.680417  0.651803
# 1  4222573799.parquet     Fp1       1  0.052783  0.759541  0.522805  1.339967
# 2  4222573799.parquet     Fp1       2 -0.022141  1.035226 -0.160490  0.860987
# 3  4222573799.parquet     Fp1       3 -0.005745  0.736341  0.477310  0.794439
# 4  4222573799.parquet     Fp1       4 -0.072732  0.902743  0.223569  1.138052
#
#         rms  zero_crossing_rate  mean_abs  ...     delta     theta    alpha1  \
# 0  0.814751             0.06875  0.631832  ...  1.302267  1.309814  0.392684
# 1  0.873114             0.09250  0.646997  ...  1.786055  0.774947  0.328054
# 2  1.017702             0.07125  0.756605  ...  1.864604  1.645849  0.382863
# 3  0.858123             0.08750  0.662660  ...  1.543197  1.198080  0.646517
# 4  0.952908             0.06000  0.724174  ...  2.154641  1.003048  0.519177
#
#      alpha2     beta1     beta2    gamma1    gamma2    higher  \
# 0  0.528421  0.545726  1.728449  1.025284  0.700820  1.971930
# 1  0.521984  0.713624  1.802032  0.947015  0.781442  1.604427
# 2  0.813415  0.782918  1.913543  0.818001  0.778454  2.161938
# 3  0.377365  0.845956  1.691956  0.923076  0.737361  1.788261
# 4  0.483029  0.634443  1.489249  0.846804  0.618220  1.414542
#
#    spectral_entropy
# 0         25.206864
# 1         24.233662
# 2         28.655877
# 3         26.224426
# 4         22.984820
#
# [5 rows x 22 columns]
